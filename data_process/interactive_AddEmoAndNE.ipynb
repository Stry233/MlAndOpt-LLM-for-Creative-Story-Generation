# %%
# libraries
import pandas as pd
import numpy as np
from pandas import DataFrame
import transformers
import sng_parser
import torch

from tqdm import tqdm

from concurrent.futures import ThreadPoolExecutor

from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from transformers import pipeline

emotion_classifier = "Yuetian/roberta-large-finetuned-plutchik-emotion" # classifier "context --> emotion(8)"

# %% [markdown]
# # Read all data

# %%
storyData = pd.read_csv('./Archive-ROCStories/analyze/ns_formated.csv')
storyData
# Out:
#                                                  question  \
# 0       Lisa woke up and covered herself in a set of b...
# 1       Bob laid out an extension cord outside for doi...
# 2                                Eric was in high school.
# 3       After I skipped detention all week, I got call...
# 4       Carter was all dressed in his soccer uniform. ...
# ...                                                   ...
# 408578  I bought a car a few months ago. I thought I w...
# 408579  I used to go to a Starbucks in my old town. Th...
# 408580  Mom always used to stitch up my teddy bear. Wh...
# 408581                              Bob was very nervous!
# 408582  I loved beef jerky. I decided to make homemade...
#
#                                                    answer
# 0       She remained in bed for another hour since she...
# 1                 He worked towards the edge of his yard.
# 2       And he had a hard time finding a job for someo...
# 3                         They said yes, so he let it go.
# 4                       Carter couldn't wait to see them!
# ...                                                   ...
# 408578  I did a few changes and had friends help with ...
# 408579  Finally before I moved she did spell my name r...
# 408580     So instead I began to patch up my little bear.
# 408581                    It was performance review time.
# 408582  It was so tasty I decided to open a jerky busi...
#
# [408583 rows x 2 columns]

# %%
storyData = pd.read_csv('./ROC_clean.csv')
storyData
# Out:
#                                                  question  \
# 0       Lisa woke up and covered herself in a set of b...
# 1       Bob laid out an extension cord outside for doi...
# 2                                Eric was in high school.
# 3       After I skipped detention all week, I got call...
# 4       Carter was all dressed in his soccer uniform. ...
# ...                                                   ...
# 408578  I bought a car a few months ago. I thought I w...
# 408579  I used to go to a Starbucks in my old town. Th...
# 408580  Mom always used to stitch up my teddy bear. Wh...
# 408581                              Bob was very nervous!
# 408582  I loved beef jerky. I decided to make homemade...
#
#                                                    answer  \
# 0       She remained in bed for another hour since she...
# 1                 He worked towards the edge of his yard.
# 2       And he had a hard time finding a job for someo...
# 3                         They said yes, so he let it go.
# 4                       Carter couldn't wait to see them!
# ...                                                   ...
# 408578  I did a few changes and had friends help with ...
# 408579  Finally before I moved she did spell my name r...
# 408580     So instead I began to patch up my little bear.
# 408581                    It was performance review time.
# 408582  It was so tasty I decided to open a jerky busi...
#
#                                               context_all  \
# 0       Lisa woke up and covered herself in a set of b...
# 1       Bob laid out an extension cord outside for doi...
# 2       Eric was in high school. And he had a hard tim...
# 3       After I skipped detention all week, I got call...
# 4       Carter was all dressed in his soccer uniform. ...
# ...                                                   ...
# 408578  I bought a car a few months ago. I thought I w...
# 408579  I used to go to a Starbucks in my old town. Th...
# 408580  Mom always used to stitch up my teddy bear. Wh...
# 408581  Bob was very nervous! It was performance revie...
# 408582  I loved beef jerky. I decided to make homemade...
#
#                                                   emotion  \
# 0       [[{'label': 'surprise', 'score': 0.99998295307...
# 1       [[{'label': 'anticipation', 'score': 0.9999402...
# 2       [[{'label': 'sadness', 'score': 0.999974727630...
# 3       [[{'label': 'joy', 'score': 0.927524209022522}...
# 4       [[{'label': 'anticipation', 'score': 0.9999876...
# ...                                                   ...
# 408578  [[{'label': 'joy', 'score': 0.9999947547912598...
# 408579  [[{'label': 'joy', 'score': 0.9998764991760254...
# 408580  [[{'label': 'trust', 'score': 0.99998247623443...
# 408581  [[{'label': 'fear', 'score': 0.999987363815307...
# 408582  [[{'label': 'joy', 'score': 0.999880313873291}...
#
#                                         keywords  \
# 0                    She, bed, another hour, she
# 1                         He, the edge, his yard
# 2       he, a hard time, a job, someone, his age
# 3                                   They, he, it
# 4                                   Carter, them
# ...                                          ...
# 408578         I, a few changes, friends, others
# 408579                   I, she, my name, my cup
# 408580                         I, my little bear
# 408581               It, performance review time
# 408582                   It, I, a jerky business
#
#                                         filtered_emotions
# 0       ['surprise', 'anger', 'sadness', 'anticipation...
# 1                        ['anticipation', 'trust', 'joy']
# 2                 ['sadness', 'fear', 'anger', 'disgust']
# 3                                        ['joy', 'trust']
# 4                                 ['anticipation', 'joy']
# ...                                                   ...
# 408578       ['joy', 'trust', 'surprise', 'anticipation']
# 408579                                            ['joy']
# 408580        ['trust', 'sadness', 'anticipation', 'joy']
# 408581                           ['fear', 'anticipation']
# 408582                   ['joy', 'anticipation', 'trust']
#
# [408583 rows x 6 columns]

# %% [markdown]
# # Get emotion data

# %%
classifier = pipeline("text-classification", model=emotion_classifier, tokenizer=emotion_classifier, top_k=None, device=0)
storyData["context_all"] = storyData["question"] + " " + storyData["answer"]

# %%
def add_emotion_column(df, input_column, output_column):
    tqdm.pandas(desc="Processing")
    df[output_column] = df[input_column].progress_apply(classifier)
    return df

# %%
# Add the new column with the keywords
storyData = add_emotion_column(storyData, input_column="context_all", output_column="emotion")
storyData
# Out:
# Processing:   0%|                                                                | 10/408583 [00:00<6:10:52, 18.36it/s]C:\Python\miniconda3\envs\general_PyTorch_GPU\lib\site-packages\transformers\pipelines\base.py:1043: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Processing: 100%|████████████████████████████████████████████████████████████| 408583/408583 [4:00:26<00:00, 28.32it/s]
#                                                  question  \
# 0       Lisa woke up and covered herself in a set of b...
# 1       Bob laid out an extension cord outside for doi...
# 2                                Eric was in high school.
# 3       After I skipped detention all week, I got call...
# 4       Carter was all dressed in his soccer uniform. ...
# ...                                                   ...
# 408578  I bought a car a few months ago. I thought I w...
# 408579  I used to go to a Starbucks in my old town. Th...
# 408580  Mom always used to stitch up my teddy bear. Wh...
# 408581                              Bob was very nervous!
# 408582  I loved beef jerky. I decided to make homemade...
#
#                                                    answer  \
# 0       She remained in bed for another hour since she...
# 1                 He worked towards the edge of his yard.
# 2       And he had a hard time finding a job for someo...
# 3                         They said yes, so he let it go.
# 4                       Carter couldn't wait to see them!
# ...                                                   ...
# 408578  I did a few changes and had friends help with ...
# 408579  Finally before I moved she did spell my name r...
# 408580     So instead I began to patch up my little bear.
# 408581                    It was performance review time.
# 408582  It was so tasty I decided to open a jerky busi...
#
#                                               context_all  \
# 0       Lisa woke up and covered herself in a set of b...
# 1       Bob laid out an extension cord outside for doi...
# 2       Eric was in high school. And he had a hard tim...
# 3       After I skipped detention all week, I got call...
# 4       Carter was all dressed in his soccer uniform. ...
# ...                                                   ...
# 408578  I bought a car a few months ago. I thought I w...
# 408579  I used to go to a Starbucks in my old town. Th...
# 408580  Mom always used to stitch up my teddy bear. Wh...
# 408581  Bob was very nervous! It was performance revie...
# 408582  I loved beef jerky. I decided to make homemade...
#
#                                                   emotion
# 0       [[{'label': 'surprise', 'score': 0.99998295307...
# 1       [[{'label': 'anticipation', 'score': 0.9999402...
# 2       [[{'label': 'sadness', 'score': 0.999974727630...
# 3       [[{'label': 'joy', 'score': 0.927524209022522}...
# 4       [[{'label': 'anticipation', 'score': 0.9999876...
# ...                                                   ...
# 408578  [[{'label': 'joy', 'score': 0.9999947547912598...
# 408579  [[{'label': 'joy', 'score': 0.9998764991760254...
# 408580  [[{'label': 'trust', 'score': 0.99998247623443...
# 408581  [[{'label': 'fear', 'score': 0.999987363815307...
# 408582  [[{'label': 'joy', 'score': 0.999880313873291}...
#
# [408583 rows x 4 columns]

# %% [markdown]
# # Get named entity data

# %%
def genKeyword(demoSentenceInput):
    graph = sng_parser.parse(demoSentenceInput)
    # print(graph)
    majorKeyword = [x['span'] for x in graph['entities']]
    return ", ".join( key for key in majorKeyword)

def add_keyword_column(df, input_column, output_column):
    tqdm.pandas(desc="Processing")
    df[output_column] = df[input_column].progress_apply(genKeyword)
    return df

def get_high_score_labels(emotions_list):
    return [item['label'] for item in emotions_list[0] if item['score'] >= 0.5]

# %%
# Add the new column with the keywords
storyData = add_keyword_column(storyData, input_column="answer", output_column="keywords")
storyData
# Out:
# Processing: 100%|█████████████████████████████████████████████████████████████| 408583/408583 [19:25<00:00, 350.43it/s]
#                                                  question  \
# 0       Lisa woke up and covered herself in a set of b...
# 1       Bob laid out an extension cord outside for doi...
# 2                                Eric was in high school.
# 3       After I skipped detention all week, I got call...
# 4       Carter was all dressed in his soccer uniform. ...
# ...                                                   ...
# 408578  I bought a car a few months ago. I thought I w...
# 408579  I used to go to a Starbucks in my old town. Th...
# 408580  Mom always used to stitch up my teddy bear. Wh...
# 408581                              Bob was very nervous!
# 408582  I loved beef jerky. I decided to make homemade...
#
#                                                    answer  \
# 0       She remained in bed for another hour since she...
# 1                 He worked towards the edge of his yard.
# 2       And he had a hard time finding a job for someo...
# 3                         They said yes, so he let it go.
# 4                       Carter couldn't wait to see them!
# ...                                                   ...
# 408578  I did a few changes and had friends help with ...
# 408579  Finally before I moved she did spell my name r...
# 408580     So instead I began to patch up my little bear.
# 408581                    It was performance review time.
# 408582  It was so tasty I decided to open a jerky busi...
#
#                                               context_all  \
# 0       Lisa woke up and covered herself in a set of b...
# 1       Bob laid out an extension cord outside for doi...
# 2       Eric was in high school. And he had a hard tim...
# 3       After I skipped detention all week, I got call...
# 4       Carter was all dressed in his soccer uniform. ...
# ...                                                   ...
# 408578  I bought a car a few months ago. I thought I w...
# 408579  I used to go to a Starbucks in my old town. Th...
# 408580  Mom always used to stitch up my teddy bear. Wh...
# 408581  Bob was very nervous! It was performance revie...
# 408582  I loved beef jerky. I decided to make homemade...
#
#                                                   emotion  \
# 0       [[{'label': 'surprise', 'score': 0.99998295307...
# 1       [[{'label': 'anticipation', 'score': 0.9999402...
# 2       [[{'label': 'sadness', 'score': 0.999974727630...
# 3       [[{'label': 'joy', 'score': 0.927524209022522}...
# 4       [[{'label': 'anticipation', 'score': 0.9999876...
# ...                                                   ...
# 408578  [[{'label': 'joy', 'score': 0.9999947547912598...
# 408579  [[{'label': 'joy', 'score': 0.9998764991760254...
# 408580  [[{'label': 'trust', 'score': 0.99998247623443...
# 408581  [[{'label': 'fear', 'score': 0.999987363815307...
# 408582  [[{'label': 'joy', 'score': 0.999880313873291}...
#
#                                         keywords
# 0                    She, bed, another hour, she
# 1                         He, the edge, his yard
# 2       he, a hard time, a job, someone, his age
# 3                                   They, he, it
# 4                                   Carter, them
# ...                                          ...
# 408578         I, a few changes, friends, others
# 408579                   I, she, my name, my cup
# 408580                         I, my little bear
# 408581               It, performance review time
# 408582                   It, I, a jerky business
#
# [408583 rows x 5 columns]

# %%
storyData['filtered_emotions'] = storyData_emoclean['emotion'].apply(get_high_score_labels)

# %%
storyData.to_csv('ROC_clean.csv', index=False)
